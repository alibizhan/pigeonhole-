# %% [markdown]
# <a href="https://colab.research.google.com/github/alibizhan/pigeonhole-/blob/master/pigoenHolePrinciple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # The Pigeonhole principle
# The pigeonhole principle states that if n items are put into m containers, with n > m, then at least one container must contain more than one item.
#
#
# ![pigeonhole-principle.webp](data:image/webp;base64,...)

# %% [markdown]
# 1. How many cards must be selected from a standard deck of 52 cards to
# guarantee that at least three cards are of the same suit ?
#
# Solution: The “boxes” are 4 suits, so the minimum is n = 9 cards, because n
# 4 > 2 is
# needed to get 3 cards of the same color.

# %%
allCards = 52
suits = 4
sameSuits = 3

minCards = (suits*(sameSuits-1))+1
print(minCards)
# Out:
# 9

# %% [markdown]
# 2. Show that in a 8×8 grid, it is impossible to place 9 rooks so that they all
# don’t threaten each other.
#
#
# Solution:
# By Pigeonhole, there exists one row with at least two rooks, so they must
# threaten each other.
